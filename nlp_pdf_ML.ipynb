# %% [markdown]
# ## PARSE SCIENTIFIC JOURNAL PDF FILES AND EXTRACT SPECIFIC KEYWORDS SUCH AS: TAXONOMY, NSC (UNIQUE IDENTIFIER), AUTHORS, COMPOUND NAMES

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from IPython.display import display
import spacy
import re
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import csv
# Out:
# Using TensorFlow backend.

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;.]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))
SHORTWORD = re.compile(r'\W*\b\w{1,3}\b')

stop_words_lst = ['cell','spectral','data','double','bond','barrier','soluble']

def clean_text(text):
    """
        text: a string

        return: modified initial string
    """
    text = str(text).lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing.
    text = re.sub(r'\b[a-zA-Z]\b','',str(text)) # remove single letter words
    text = re.sub('\d+','',text) # remove digits
    text = SHORTWORD.sub('',text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    for w in stop_words_lst:
        pattern = r'\b'+w+r'\b'
        text = re.sub(pattern, '', str(text))

    return text

# %% [markdown]
# ### taxonomy names from csv

# %%
import pandas as pd
import numpy as np
taxon_file = 'taxon_names.csv'
taxon_name_df = pd.read_csv(taxon_file)
#taxon_name_df.head(150)
# unit_name1 + unit_name2 is the full taxonomy name; can just make a set of each column

taxon_name_df = taxon_name_df.replace(np.nan, '', regex=True)
taxon_name_df["name"] = taxon_name_df.iloc[:, 0] + " "+ taxon_name_df.iloc[:, 1]

# %% [markdown]
# ### open pdf file for testing

# %%
with open('np50121a025.pdf_OUTPUT.txt', 'r', encoding="latin-1") as f:
    read_output = f.readlines()
read_output = '\n'.join(read_output).strip().replace('\n','')
#read_output

# %% [markdown]
# Clean the text, get bigrams and apply TFIDF

# %%
pdf_o = clean_text(read_output)
text_tokens = word_tokenize(pdf_o)

pdf_i=[pdf_o]

# Getting bigrams  
vectorizer = CountVectorizer(ngram_range =(2, 2)) 
X1 = vectorizer.fit_transform(pdf_i)  
features = (vectorizer.get_feature_names()) 
#print("\n\nX1 : \n", X1.toarray()) 
  
# Applying TFIDF 
# You can still get n-grams here 
X2 = vectorizer.fit_transform(pdf_i) 
scores = (X2.toarray()) 
#print("\n\nScores : \n", scores) 
  
# Getting top ranking features 
sums = X2.sum(axis = 0) 
data1 = [] 
for col, term in enumerate(features): 
    data1.append( (term, sums[0, col] )) 
ranking = pd.DataFrame(data1, columns = ['term', 'rank']) 
words = (ranking.sort_values('rank', ascending = False)) 
print ("\n\nWords : \n", words.head(50))
# Out:
# Words :
#                         term  rank
# 234    cytotoxic macrolides     4
# 574          methine proton     3
# 580            methyl group     3
# 759        rashid cytotoxic     3
# 639               ncih ncih     3
# 709  polyoxazole macrolides     3
# 675             ovcar ovcar     3
# 455      indole derivatives     3
# 538    macrolides tubastreu     3
# 415       hmbc correlations     3
# 483             july rashid     3
# 601       molecular formula     3
# 481         journal natural     3
# 81                boyd prod     2
# 206            corals genus     2
# 148            cnmr signals     2
# 679           oxazole rings     2
# 692   partitioning protocol     2
# 697     permeation sephadex     2
# 557     matsunaga hashimoto     2
# 556      matsunaga fusetani     2
# 779     reported mycalolide     2
# 49       antitumor activity     2
# 428           hrfabms calcd     2
# 192          confirmed hmbc     2
# 425               hplc give     2
# 618     mycalolide isolated     2
# 374        give mycalolides     2
# 378              great reef     2
# 135         class macrolide     2
# 158    collection tubastreu     2
# 620   mycalolide mycalolide     2
# 127          chem matsunaga     2
# 125             chem kernan     2
# 891          subjected diol     2
# 392    gustafson cardellina     2
# 613    mycalolide colorless     2
# 611   mycalolide additional     2
# 880             stony coral     2
# 175      comparison related     2
# 664         olefinic proton     2
# 775       related compounds     2
# 635        natural products     2
# 977       vicinal couplings     2
# 979       voucher specimens     2
# 956     tubastreu faulkneri     2
# 241        deamino demethyl     2
# 493             koseki noma     2
# 267               diol hplc     2
# 514     liquid partitioning     2

# %%
def extract_candidate_words(text, good_tags=set(['JJ','JJR','JJS','NN','NNP','NNS','NNPS'])):
    import itertools, nltk, string

    # exclude candidates that are stop words or entirely punctuation
    punct = set(string.punctuation)
    stop_words = set(nltk.corpus.stopwords.words('english'))
    # tokenize and POS-tag words
    tagged_words = itertools.chain.from_iterable(nltk.pos_tag_sents(nltk.word_tokenize(sent)
                                                                    for sent in nltk.sent_tokenize(text)))
    # filter on certain POS tags and lowercase all words
    candidates = [word.lower() for word, tag in tagged_words
                  if tag in good_tags and word.lower() not in stop_words
                  and not all(char in punct for char in word)]

    return candidates

candidates = extract_candidate_words(pdf_o)

# %%
def score_keyphrases_by_textrank(text, n_keywords=0.05):
    from itertools import takewhile, tee
    import networkx, nltk
    
    # tokenize for all words, and extract *candidate* words
    words = [word.lower()
             for sent in nltk.sent_tokenize(text)
             for word in nltk.word_tokenize(sent)]
    candidates = extract_candidate_words(text)
    # build graph, each node is a unique candidate
    graph = networkx.Graph()
    graph.add_nodes_from(set(candidates))
    # iterate over word-pairs, add unweighted edges into graph
    def pairwise(iterable):
        """s -> (s0,s1), (s1,s2), (s2, s3), ..."""
        a, b = tee(iterable)
        next(b, None)
        return zip(a, b)
    for w1, w2 in pairwise(candidates):
        if w2:
            graph.add_edge(*sorted([w1, w2]))
    # score nodes using default pagerank algorithm, sort by score, keep top n_keywords
    ranks = networkx.pagerank(graph)
    if 0 < n_keywords < 1:
        n_keywords = int(round(len(candidates) * n_keywords))
    word_ranks = {word_rank[0]: word_rank[1]
                  for word_rank in sorted(ranks.items(), key=lambda x: x[1], reverse=True)[:n_keywords]}
    keywords = set(word_ranks.keys())
    # merge keywords into keyphrases
    keyphrases = {}
    j = 0
    for i, word in enumerate(words):
        if i < j:
            continue
        if word in keywords:
            kp_words = list(takewhile(lambda x: x in keywords, words[i:i+10]))
            avg_pagerank = sum(word_ranks[w] for w in kp_words) / float(len(kp_words))
            keyphrases[' '.join(kp_words)] = avg_pagerank
            # counter as hackish way to ensure merged keyphrases are non-overlapping
            j = i + len(kp_words)
    
    return sorted(keyphrases.items(), key=lambda x: x[1], reverse=True)

score_keyphrases_by_textrank(pdf_o)
# Out:
# [('compound', 0.009002985938699571),
#  ('mycalolide', 0.008471707156256671),
#  ('compound mycalolides', 0.007869783658570169),
#  ('group compound', 0.007829748346955101),
#  ('compound mycalolide macrolide', 0.007659606187557596),
#  ('macrolides', 0.007368559539504916),
#  ('structure mycalolide mycalolide', 0.007105108694676805),
#  ('macrolides mycalolides', 0.007052570458972842),
#  ('fraction', 0.00698846434769412),
#  ('chem', 0.0069293682612516835),
#  ('methyl mycalolide', 0.0067766867504236656),
#  ('mycalolide collection', 0.006753312578151906),
#  ('mycalolides', 0.006736581378440768),
#  ('group', 0.006656510755210632),
#  ('similar mycalolide', 0.006602600729552704),
#  ('mixture macrolides', 0.0065957242259657815),
#  ('class compound', 0.006467983452641953),
#  ('extract', 0.006400905435343411),
#  ('mycalolides cytotoxic macrolides collection', 0.006357451325919899),
#  ('cytotoxic extract', 0.006345325910515091),
#  ('similar mixture mycalolide', 0.006342696790510686),
#  ('cytotoxic', 0.006289746385686772),
#  ('mycalolides mycalolide mycalolide hmbc correlations',
#   0.0062453538609948175),
#  ('oxazole imide mycalolide', 0.006119413276943683),
#  ('methyl group', 0.005869088549900646),
#  ('hplc', 0.005852681527392245),
#  ('mixture', 0.005822888912426648),
#  ('group imide', 0.0057581802440966594),
#  ('imide group', 0.0057581802440966594),
#  ('extract faulkneri', 0.0057341821096107),
#  ('rashid cytotoxic macrolides', 0.005729379668290529),
#  ('macrolide mixture hplc', 0.005726565302511813),
#  ('macrolide', 0.005504125467716545),
#  ('faulkner chem', 0.005494281996618543),
#  ('comparison', 0.005493893251058013),
#  ('meoh', 0.005493027445912592),
#  ('methyl group similar', 0.005490557134216676),
#  ('chem lett', 0.005458917549441495),
#  ('methyl group protons', 0.005447109299609978),
#  ('proton', 0.005413336584488374),
#  ('similar hplc', 0.005293087915120491),
#  ('diol hplc', 0.0052174050272709325),
#  ('macrolide imide', 0.005181987600349616),
#  ('methyl', 0.00508166634459066),
#  ('faulkneri', 0.005067458783877989),
#  ('collection', 0.0050349180000471404),
#  ('oxazole', 0.005026682941591688),
#  ('cytotoxicity', 0.004970992444891539),
#  ('boyd', 0.00486570300034882),
#  ('macrolide cnmr', 0.004860596511949703),
#  ('imide', 0.004859849732982688),
#  ('methyl protons', 0.004842408571809651),
#  ('similar', 0.004733494302848737),
#  ('tion', 0.004722742435231846),
#  ('class macrolide', 0.0047185532171504395),
#  ('cardellina', 0.004660825454811839),
#  ('protons', 0.004603150799028642),
#  ('diol', 0.00458212852714962),
#  ('class methyl', 0.004507323655587497),
#  ('structure', 0.004371911771517075),
#  ('cardellina boyd prod', 0.00432385133883534),
#  ('cnmr', 0.004217067556182861),
#  ('tion tubastrea', 0.004201332064069082),
#  ('boyd prod', 0.00415536428084709),
#  ('faulkner', 0.004059195731985403),
#  ('lett', 0.003988466837631306),
#  ('correlations', 0.0039030385257433175),
#  ('values', 0.0038173278830319225),
#  ('hmbc correlations', 0.0037733868070099876),
#  ('indole', 0.003686037412661601),
#  ('tubastrea', 0.0036799216929063188),
#  ('hmbc', 0.003643735088276658),
#  ('rashid', 0.0035298330796798994),
#  ('prod rashid', 0.0034874293205126305),
#  ('identical', 0.0034253066467588985)]

# %%
def extract_candidate_features(candidates, doc_text, doc_excerpt, doc_title):
    import collections, math, nltk, re
    
    candidate_scores = collections.OrderedDict()
    
    # get word counts for document
    doc_word_counts = collections.Counter(word.lower()
                                          for sent in nltk.sent_tokenize(doc_text)
                                          for word in nltk.word_tokenize(sent))
    
    for candidate in candidates:
        
        pattern = re.compile(r'\b'+re.escape(candidate)+r'(\b|[,;.!?]|\s)', re.IGNORECASE)
        
        # frequency-based
        # number of times candidate appears in document
        cand_doc_count = len(pattern.findall(doc_text))
        # count could be 0 for multiple reasons; shit happens in a simplified example
        if not cand_doc_count:
            print('**WARNING:', candidate, 'not found!')
            continue
    
        # statistical
        candidate_words = candidate.split()
        max_word_length = max(len(w) for w in candidate_words)
        term_length = len(candidate_words)
        # get frequencies for term and constituent words
        sum_doc_word_counts = float(sum(doc_word_counts[w] for w in candidate_words))
        try:
            # lexical cohesion doesn't make sense for 1-word terms
            if term_length == 1:
                lexical_cohesion = 0.0
            else:
                lexical_cohesion = term_length * (1 + math.log(cand_doc_count, 10)) * cand_doc_count / sum_doc_word_counts
        except (ValueError, ZeroDivisionError) as e:
            lexical_cohesion = 0.0
        
        # positional
        # found in title, key excerpt
        in_title = 1 if pattern.search(doc_title) else 0
        in_excerpt = 1 if pattern.search(doc_excerpt) else 0
        # first/last position, difference between them (spread)
        doc_text_length = float(len(doc_text))
        first_match = pattern.search(doc_text)
        abs_first_occurrence = first_match.start() / doc_text_length
        if cand_doc_count == 1:
            spread = 0.0
            abs_last_occurrence = abs_first_occurrence
        else:
            for last_match in pattern.finditer(doc_text):
                pass
            abs_last_occurrence = last_match.start() / doc_text_length
            spread = abs_last_occurrence - abs_first_occurrence

        candidate_scores[candidate] = {'term_count': cand_doc_count,
                                       'term_length': term_length, 'max_word_length': max_word_length,
                                       'spread': spread, 'lexical_cohesion': lexical_cohesion,
                                       'in_excerpt': in_excerpt, 'in_title': in_title,
                                       'abs_first_occurrence': abs_first_occurrence,
                                       'abs_last_occurrence': abs_last_occurrence}

    return candidate_scores

extract_candidate_features(candidates,pdf_o,pdf_o,'doc title')
# Out:
# OrderedDict([('journal',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.543336236933798,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0,
#                'abs_last_occurrence': 0.543336236933798}),
#              ('natural',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.5433362369337978,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0008710801393728223,
#                'abs_last_occurrence': 0.5442073170731707}),
#              ('praducts',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0017421602787456446,
#                'abs_last_occurrence': 0.0017421602787456446}),
#              ('mycalolides',
#               {'term_count': 8,
#                'term_length': 1,
#                'max_word_length': 11,
#                'spread': 0.7481489547038327,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0032665505226480837,
#                'abs_last_occurrence': 0.7514155052264808}),
#              ('macrolides',
#               {'term_count': 11,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.8227351916376306,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.005662020905923345,
#                'abs_last_occurrence': 0.828397212543554}),
#              ('collection',
#               {'term_count': 5,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.6880444250871081,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.006859756097560976,
#                'abs_last_occurrence': 0.694904181184669}),
#              ('stony',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 5,
#                'spread': 0.0628266550522648,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.008057491289198606,
#                'abs_last_occurrence': 0.07088414634146341}),
#              ('coral',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 5,
#                'spread': 0.031141114982578398,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.008710801393728223,
#                'abs_last_occurrence': 0.03985191637630662}),
#              ('tubastrea',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.8780487804878049,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.009364111498257839,
#                'abs_last_occurrence': 0.8874128919860628}),
#              ('faulmverl',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.010452961672473868,
#                'abs_last_occurrence': 0.010452961672473868}),
#              ('mohmimd',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.011541811846689896,
#                'abs_last_occurrence': 0.011541811846689896}),
#              ('rashid',
#               {'term_count': 5,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.9768074912891985,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.012412891986062718,
#                'abs_last_occurrence': 0.9892203832752613}),
#              ('kirk',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.013175087108013937,
#                'abs_last_occurrence': 0.013175087108013937}),
#              ('gustafson',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.9807273519163764,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.013719512195121951,
#                'abs_last_occurrence': 0.9944468641114983}),
#              ('john',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.014808362369337979,
#                'abs_last_occurrence': 0.014808362369337979}),
#              ('cardellina',
#               {'term_count': 4,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.9801829268292683,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.015352787456445994,
#                'abs_last_occurrence': 0.9955357142857143}),
#              ('michael',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.016550522648083623,
#                'abs_last_occurrence': 0.016550522648083623}),
#              ('lcrbwatwy',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.01796602787456446,
#                'abs_last_occurrence': 0.01796602787456446}),
#              ('drug',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.019054878048780487,
#                'abs_last_occurrence': 0.019054878048780487}),
#              ('discwey',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0195993031358885,
#                'abs_last_occurrence': 0.0195993031358885}),
#              ('resurcb',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.020470383275261322,
#                'abs_last_occurrence': 0.020470383275261322}),
#              ('deveiopnt',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.021341463414634148,
#                'abs_last_occurrence': 0.021341463414634148}),
#              ('developmntal',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 12,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.022430313588850174,
#                'abs_last_occurrence': 0.022430313588850174}),
#              ('thapeuticrs',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 11,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.02384581881533101,
#                'abs_last_occurrence': 0.02384581881533101}),
#              ('program',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.025152439024390245,
#                'abs_last_occurrence': 0.025152439024390245}),
#              ('division',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.026023519163763068,
#                'abs_last_occurrence': 0.026023519163763068}),
#              ('cancer',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0028310104529616735,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.02700348432055749,
#                'abs_last_occurrence': 0.029834494773519165}),
#              ('treatment',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.02776567944250871,
#                'abs_last_occurrence': 0.02776567944250871}),
#              ('national',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.028854529616724738,
#                'abs_last_occurrence': 0.028854529616724738}),
#              ('institute',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.6502613240418118,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.03059668989547038,
#                'abs_last_occurrence': 0.6808580139372822}),
#              ('frederick',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.03266550522648084,
#                'abs_last_occurrence': 0.03266550522648084}),
#              ('maryland',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.033754355400696864,
#                'abs_last_occurrence': 0.033754355400696864}),
#              ('abstract',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.03473432055749129,
#                'abs_last_occurrence': 0.03473432055749129}),
#              ('fractionation',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 13,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.03571428571428571,
#                'abs_last_occurrence': 0.03571428571428571}),
#              ('cytotoxic',
#               {'term_count': 10,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.8227351916376308,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.004573170731707317,
#                'abs_last_occurrence': 0.827308362369338}),
#              ('extract',
#               {'term_count': 6,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.6798780487804877,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.03832752613240418,
#                'abs_last_occurrence': 0.7182055749128919}),
#              ('tubastru',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.04050522648083624,
#                'abs_last_occurrence': 0.04050522648083624}),
#              ('faulkneri',
#               {'term_count': 5,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.5941855400696864,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.04148519163763066,
#                'abs_last_occurrence': 0.635670731707317}),
#              ('series',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.04344512195121951,
#                'abs_last_occurrence': 0.04344512195121951}),
#              ('polyoxazole',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 11,
#                'spread': 0.6020252613240419,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.04529616724738676,
#                'abs_last_occurrence': 0.6473214285714286}),
#              ('several',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.11835801393728224,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.047800522648083626,
#                'abs_last_occurrence': 0.16615853658536586}),
#              ('noncytotoxic',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 12,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.04867160278745645,
#                'abs_last_occurrence': 0.04867160278745645}),
#              ('indole',
#               {'term_count': 4,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.7197299651567944,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.05008710801393728,
#                'abs_last_occurrence': 0.7698170731707317}),
#              ('derivatives',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 11,
#                'spread': 0.15908101045296166,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0508493031358885,
#                'abs_last_occurrence': 0.20993031358885017}),
#              ('identified',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.1555966898954704,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.055640243902439025,
#                'abs_last_occurrence': 0.21123693379790942}),
#              ('addition',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.05683797909407665,
#                'abs_last_occurrence': 0.05683797909407665}),
#              ('compound',
#               {'term_count': 9,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.7934451219512195,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.058471254355400695,
#                'abs_last_occurrence': 0.8519163763066202}),
#              ('mycalolide',
#               {'term_count': 17,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.7552264808362369,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.05945121951219512,
#                'abs_last_occurrence': 0.814677700348432}),
#              ('macrolide',
#               {'term_count': 7,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.373911149825784,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.060648954703832754,
#                'abs_last_occurrence': 0.43456010452961674}),
#              ('structures',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.06173780487804878,
#                'abs_last_occurrence': 0.06173780487804878}),
#              ('detailed',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.06413327526132404,
#                'abs_last_occurrence': 0.06413327526132404}),
#              ('analysis',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.4691855400696864,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.06511324041811847,
#                'abs_last_occurrence': 0.5342987804878049}),
#              ('spectroscopic',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 13,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0660932055749129,
#                'abs_last_occurrence': 0.0660932055749129}),
#              ('comparison',
#               {'term_count': 6,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.44120209059233445,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.06772648083623693,
#                'abs_last_occurrence': 0.5089285714285714}),
#              ('related',
#               {'term_count': 4,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.47158101045296164,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.06892421602787456,
#                'abs_last_occurrence': 0.5405052264808362}),
#              ('compounds',
#               {'term_count': 5,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.7630662020905923,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.06979529616724739,
#                'abs_last_occurrence': 0.8328614982578397}),
#              ('scleractinian',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 13,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.07153745644599303,
#                'abs_last_occurrence': 0.07153745644599303}),
#              ('corals',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.5786149825783973,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.07306184668989547,
#                'abs_last_occurrence': 0.6516768292682927}),
#              ('tubastreu',
#               {'term_count': 6,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.7551175958188153,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0744773519163763,
#                'abs_last_occurrence': 0.8295949477351916}),
#              ('dendrophylliidae',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 16,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.07556620209059234,
#                'abs_last_occurrence': 0.07556620209059234}),
#              ('source',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.078397212543554,
#                'abs_last_occurrence': 0.078397212543554}),
#              ('biologi',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.07915940766550522,
#                'abs_last_occurrence': 0.07915940766550522}),
#              ('active',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.08068379790940766,
#                'abs_last_occurrence': 0.08068379790940766}),
#              ('alkaloids',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.03397212543554007,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.08144599303135888,
#                'abs_last_occurrence': 0.11541811846689895}),
#              ('aplysinopsin',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 12,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.08362369337979095,
#                'abs_last_occurrence': 0.08362369337979095}),
#              ('brominated',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.0859102787456446,
#                'abs_last_occurrence': 0.0859102787456446}),
#              ('contain',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.09102787456445993,
#                'abs_last_occurrence': 0.09102787456445993}),
#              ('australian',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.5844947735191638,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.09516550522648083,
#                'abs_last_occurrence': 0.6796602787456446}),
#              ('cellline',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.10213414634146341,
#                'abs_last_occurrence': 0.10213414634146341}),
#              ('antitumor',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.6368684668989547,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.10311411149825785,
#                'abs_last_occurrence': 0.7399825783972126}),
#              ('screen',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.10420296167247386,
#                'abs_last_occurrence': 0.10420296167247386}),
#              ('frac',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.010779616724738678,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.10681620209059234,
#                'abs_last_occurrence': 0.11759581881533102}),
#              ('tionation',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.10736062717770035,
#                'abs_last_occurrence': 0.10736062717770035}),
#              ('inac',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.11030052264808363,
#                'abs_last_occurrence': 0.11030052264808363}),
#              ('tive',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.11084494773519164,
#                'abs_last_occurrence': 0.11084494773519164}),
#              ('fraction',
#               {'term_count': 7,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.6771559233449477,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.11138937282229965,
#                'abs_last_occurrence': 0.7885452961672473}),
#              ('aplysinop',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1134581881533101,
#                'abs_last_occurrence': 0.1134581881533101}),
#              ('sintype',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.11454703832752614,
#                'abs_last_occurrence': 0.11454703832752614}),
#              ('tion',
#               {'term_count': 4,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.7687282229965157,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.11814024390243902,
#                'abs_last_occurrence': 0.8868684668989547}),
#              ('rich',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.11868466898954703,
#                'abs_last_occurrence': 0.11868466898954703}),
#              ('herein',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.12260452961672474,
#                'abs_last_occurrence': 0.12260452961672474}),
#              ('isolation',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.12336672473867596,
#                'abs_last_occurrence': 0.12336672473867596}),
#              ('structure',
#               {'term_count': 4,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.4447952961672474,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.12445557491289198,
#                'abs_last_occurrence': 0.5692508710801394}),
#              ('elucidation',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 11,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.125544425087108,
#                'abs_last_occurrence': 0.125544425087108}),
#              ('cytotoxicity',
#               {'term_count': 4,
#                'term_length': 1,
#                'max_word_length': 12,
#                'spread': 0.7744991289198606,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.12685104529616725,
#                'abs_last_occurrence': 0.9013501742160279}),
#              ('profile',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.12826655052264807,
#                'abs_last_occurrence': 0.12826655052264807}),
#              ('organic',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.5736062717770035,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1375217770034843,
#                'abs_last_occurrence': 0.7111280487804879}),
#              ('great',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 5,
#                'spread': 0.5332099303135889,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.140352787456446,
#                'abs_last_occurrence': 0.6735627177700348}),
#              ('reef',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.5332099303135889,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.14111498257839722,
#                'abs_last_occurrence': 0.674324912891986}),
#              ('australia',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.5342987804878049,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.14165940766550522,
#                'abs_last_occurrence': 0.6759581881533101}),
#              ('solvent',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0008710801393728151,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1438371080139373,
#                'abs_last_occurrence': 0.1447081881533101}),
#              ('protocol',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.5761106271777003,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.14699477351916376,
#                'abs_last_occurrence': 0.7231054006968641}),
#              ('activity',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.5909189895470384,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.15015243902439024,
#                'abs_last_occurrence': 0.7410714285714286}),
#              ('fractions',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.5769817073170732,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.15124128919860627,
#                'abs_last_occurrence': 0.7282229965156795}),
#              ('permeation',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.5773083623693379,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.15450783972125434,
#                'abs_last_occurrence': 0.7318162020905923}),
#              ('sephadex',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.577308362369338,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.155705574912892,
#                'abs_last_occurrence': 0.73301393728223}),
#              ('diol',
#               {'term_count': 6,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.6097560975609756,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1566855400696864,
#                'abs_last_occurrence': 0.766441637630662}),
#              ('bondedphase',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 11,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.15722996515679444,
#                'abs_last_occurrence': 0.15722996515679444}),
#              ('hplc',
#               {'term_count': 7,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.6280487804878049,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.15853658536585366,
#                'abs_last_occurrence': 0.7865853658536586}),
#              ('partition',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.16093205574912892,
#                'abs_last_occurrence': 0.16093205574912892}),
#              ('dolecarboxaldehyde',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 18,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1722560975609756,
#                'abs_last_occurrence': 0.1722560975609756}),
#              ('bromoindolecarboxaldehyde',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 25,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.17432491289198607,
#                'abs_last_occurrence': 0.17432491289198607}),
#              ('mixture',
#               {'term_count': 6,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.6243466898954704,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.17715592334494773,
#                'abs_last_occurrence': 0.8015026132404182}),
#              ('purification',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 12,
#                'spread': 0.6079050522648083,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1792247386759582,
#                'abs_last_occurrence': 0.7871297909407665}),
#              ('additional',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.5996297909407666,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.18488675958188153,
#                'abs_last_occurrence': 0.7845165505226481}),
#              ('late',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.18608449477351915,
#                'abs_last_occurrence': 0.18608449477351915}),
#              ('material',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.541920731707317,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1875,
#                'abs_last_occurrence': 0.729420731707317}),
#              ('column',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.5914634146341464,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.18902439024390244,
#                'abs_last_occurrence': 0.7804878048780488}),
#              ('afford',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.5911367595818815,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1914198606271777,
#                'abs_last_occurrence': 0.7825566202090593}),
#              ('july',
#               {'term_count': 4,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.8232796167247387,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.00272212543554007,
#                'abs_last_occurrence': 0.8260017421602788}),
#              ('yellow',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.19686411149825783,
#                'abs_last_occurrence': 0.19686411149825783}),
#              ('pigment',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.19762630662020905,
#                'abs_last_occurrence': 0.19762630662020905}),
#              ('deamino',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.5934233449477351,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1984973867595819,
#                'abs_last_occurrence': 0.791920731707317}),
#              ('demethyl',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.5934233449477352,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.1993684668989547,
#                'abs_last_occurrence': 0.7927918118466899}),
#              ('oxoaplysinopsin',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 15,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.20034843205574912,
#                'abs_last_occurrence': 0.20034843205574912}),
#              ('geometri',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.2029616724738676,
#                'abs_last_occurrence': 0.2029616724738676}),
#              ('isomers',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.5925522648083623,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.20394163763066203,
#                'abs_last_occurrence': 0.7964939024390244}),
#              ('similar',
#               {'term_count': 5,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.5958188153310104,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.20481271777003485,
#                'abs_last_occurrence': 0.8006315331010453}),
#              ('isomeric',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.20568379790940766,
#                'abs_last_occurrence': 0.20568379790940766}),
#              ('bromo',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 5,
#                'spread': 0.5913545296167247,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.20753484320557491,
#                'abs_last_occurrence': 0.7988893728222997}),
#              ('analogue',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.20818815331010454,
#                'abs_last_occurrence': 0.20818815331010454}),
#              ('physi',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 5,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.21363240418118468,
#                'abs_last_occurrence': 0.21363240418118468}),
#              ('characteristics',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 15,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.2143945993031359,
#                'abs_last_occurrence': 0.2143945993031359}),
#              ('literature',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.6866289198606272,
# ...
#              ('dnrg',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9331445993031359,
#                'abs_last_occurrence': 0.9331445993031359}),
#              ('wagenen',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9345601045296167,
#                'abs_last_occurrence': 0.9345601045296167}),
#              ('larsen',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9354311846689896,
#                'abs_last_occurrence': 0.9354311846689896}),
#              ('randarzo',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9373911149825784,
#                'abs_last_occurrence': 0.9373911149825784}),
#              ('liden',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 5,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9383710801393729,
#                'abs_last_occurrence': 0.9383710801393729}),
#              ('andc',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9390243902439024,
#                'abs_last_occurrence': 0.9390243902439024}),
#              ('chowdhury',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9414198606271778,
#                'abs_last_occurrence': 0.9414198606271778}),
#              ('chakrabolry',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 11,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9425087108013938,
#                'abs_last_occurrence': 0.9425087108013938}),
#              ('phytochemistry',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 14,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.943815331010453,
#                'abs_last_occurrence': 0.943815331010453}),
#              ('wolfe',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 5,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9463196864111498,
#                'abs_last_occurrence': 0.9463196864111498}),
#              ('andersen',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9469729965156795,
#                'abs_last_occurrence': 0.9469729965156795}),
#              ('faulkner',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.03342770034843201,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9479529616724739,
#                'abs_last_occurrence': 0.9813806620209059}),
#              ('antimicrob',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9489329268292683,
#                'abs_last_occurrence': 0.9489329268292683}),
#              ('agents',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9501306620209059,
#                'abs_last_occurrence': 0.9501306620209059}),
#              ('cafieri',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9519817073170732,
#                'abs_last_occurrence': 0.9519817073170732}),
#              ('fattorusso',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.952852787456446,
#                'abs_last_occurrence': 0.952852787456446}),
#              ('mahajanah',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9540505226480837,
#                'abs_last_occurrence': 0.9540505226480837}),
#              ('mangoni',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9551393728222997,
#                'abs_last_occurrence': 0.9551393728222997}),
#              ('naturfwsch',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 10,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9560104529616724,
#                'abs_last_occurrence': 0.9560104529616724}),
#              ('fusetani',
#               {'term_count': 4,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.059668989547038365,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.912020905923345,
#                'abs_last_occurrence': 0.9716898954703833}),
#              ('yasumuro',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9581881533101045,
#                'abs_last_occurrence': 0.9581881533101045}),
#              ('tetrahedron',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 11,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.961345818815331,
#                'abs_last_occurrence': 0.961345818815331}),
#              ('roesener',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9631968641114983,
#                'abs_last_occurrence': 0.9631968641114983}),
#              ('hashimoco',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.967661149825784,
#                'abs_last_occurrence': 0.967661149825784}),
#              ('koseki',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0050087108013937565,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.96875,
#                'abs_last_occurrence': 0.9737587108013938}),
#              ('noma',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0050087108013937565,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9695121951219512,
#                'abs_last_occurrence': 0.974520905923345}),
#              ('noguchi',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.975065331010453,
#                'abs_last_occurrence': 0.975065331010453}),
#              ('sankawa',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9759364111498258,
#                'abs_last_occurrence': 0.9759364111498258}),
#              ('molinski',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 8,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9781141114982579,
#                'abs_last_occurrence': 0.9781141114982579}),
#              ('kernan',
#               {'term_count': 2,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.003266550522648126,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9773519163763066,
#                'abs_last_occurrence': 0.9806184668989547}),
#              ('tetrahe',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9823606271777003,
#                'abs_last_occurrence': 0.9823606271777003}),
#              ('dron',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9832317073170732,
#                'abs_last_occurrence': 0.9832317073170732}),
#              ('kobayashi',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9843205574912892,
#                'abs_last_occurrence': 0.9843205574912892}),
#              ('murata',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 6,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9854094076655052,
#                'abs_last_occurrence': 0.9854094076655052}),
#              ('shigemori',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9861716027874564,
#                'abs_last_occurrence': 0.9861716027874564}),
#              ('andt',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9872604529616724,
#                'abs_last_occurrence': 0.9872604529616724}),
#              ('sasakij',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9878048780487805,
#                'abs_last_occurrence': 0.9878048780487805}),
#              ('prod',
#               {'term_count': 3,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.009146341463414642,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9886759581881533,
#                'abs_last_occurrence': 0.997822299651568}),
#              ('decosterd',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 9,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9933580139372822,
#                'abs_last_occurrence': 0.9933580139372822}),
#              ('gray',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 4,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9967334494773519,
#                'abs_last_occurrence': 0.9967334494773519}),
#              ('receiwd',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9983667247386759,
#                'abs_last_occurrence': 0.9983667247386759}),
#              ('january',
#               {'term_count': 1,
#                'term_length': 1,
#                'max_word_length': 7,
#                'spread': 0.0,
#                'lexical_cohesion': 0.0,
#                'in_excerpt': 1,
#                'in_title': 0,
#                'abs_first_occurrence': 0.9992378048780488,
#                'abs_last_occurrence': 0.9992378048780488})])
